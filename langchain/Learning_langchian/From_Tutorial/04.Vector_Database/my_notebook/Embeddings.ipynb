# %% [markdown]
# # Vector Embeddings
#
# ### Tutorial:
#
# FreeCodeCamp: [youtube](https://www.youtube.com/watch?v=yfHHvmaMkcA&ab_channel=freeCodeCamp.org)
#
# ---
#
# ![Screenshot 2024-02-04 at 10.00.07 AM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-02-04 at 10.09.24 AM.png](data:image/png;base64,...)

# %% [markdown]
# # Create Embeddings

# %%
from google.colab import userdata
openai_embeddings_key = userdata.get('Embeddings')

# %%
# !pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.0/226.0 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.9.0 which is incompatible.
# ...

# %%
from openai import OpenAI
client = OpenAI(api_key = openai_embeddings_key)

response = client.embeddings.create(
    input="The food was good and the waiter ..",
    model="text-embedding-3-small"
)

print(response.data[0].embedding)
# Out:
# [-0.04088960960507393, 0.011142821051180363, -0.05352235957980156, -0.07611864060163498, 0.027129346504807472, -0.02209005318582058, 0.017971178516745567, 0.024690236896276474, -0.032628849148750305, -0.03835845738649368, 0.005128459073603153, -0.03196154534816742, 0.0036672940477728844, -0.01005557645112276, -0.002033550525084138, -0.010751643218100071, 0.014139935374259949, -0.013668220490217209, 0.0034975919406861067, 0.031133169308304787, 0.014853260479867458, 0.011735341511666775, -0.0187535360455513, 0.00983697734773159, -0.026968274265527725, 0.008122696541249752, -0.008738227188587189, -0.007179267704486847, -6.858199776615947e-05, 0.010170629248023033, 0.0468263104557991, -0.01732688583433628, 0.017050759866833687, -0.007185020018368959, -0.015520564280450344, -0.030281782150268555, 0.04259238392114639, 0.007518671918660402, 0.03953199088573456, 0.010268423706293106, -0.02954544685781002, 0.039670053869485855, 0.028901154175400734, 0.0006518435548059642, 0.06686843186616898,
# ...

# %%
import pprint

# %%
pprint.pprint(response)
# Out:
# CreateEmbeddingResponse(data=[Embedding(embedding=[-0.04088960960507393, 0.011142821051180363, -0.05352235957980156, -0.07611864060163498, 0.027129346504807472, -0.02209005318582058, 0.017971178516745567, 0.024690236896276474, -0.032628849148750305, -0.03835845738649368, 0.005128459073603153, -0.03196154534816742, 0.0036672940477728844, -0.01005557645112276, -0.002033550525084138, -0.010751643218100071, 0.014139935374259949, -0.013668220490217209, 0.0034975919406861067, 0.031133169308304787, 0.014853260479867458, 0.011735341511666775, -0.0187535360455513, 0.00983697734773159, -0.026968274265527725, 0.008122696541249752, -0.008738227188587189, -0.007179267704486847, -6.858199776615947e-05, 0.010170629248023033, 0.0468263104557991, -0.01732688583433628, 0.017050759866833687, -0.007185020018368959, -0.015520564280450344, -0.030281782150268555, 0.04259238392114639, 0.007518671918660402, 0.03953199088573456, 0.010268423706293106, -0.02954544685781002, 0.039670053869485855, 0.0289011541754
# ...

# %%
pprint.pprint(response.data[0])
# Out:
# Embedding(embedding=[-0.04088960960507393, 0.011142821051180363, -0.05352235957980156, -0.07611864060163498, 0.027129346504807472, -0.02209005318582058, 0.017971178516745567, 0.024690236896276474, -0.032628849148750305, -0.03835845738649368, 0.005128459073603153, -0.03196154534816742, 0.0036672940477728844, -0.01005557645112276, -0.002033550525084138, -0.010751643218100071, 0.014139935374259949, -0.013668220490217209, 0.0034975919406861067, 0.031133169308304787, 0.014853260479867458, 0.011735341511666775, -0.0187535360455513, 0.00983697734773159, -0.026968274265527725, 0.008122696541249752, -0.008738227188587189, -0.007179267704486847, -6.858199776615947e-05, 0.010170629248023033, 0.0468263104557991, -0.01732688583433628, 0.017050759866833687, -0.007185020018368959, -0.015520564280450344, -0.030281782150268555, 0.04259238392114639, 0.007518671918660402, 0.03953199088573456, 0.010268423706293106, -0.02954544685781002, 0.039670053869485855, 0.028901154175400734, 0.0006518435548059642, 
# ...

# %%
pprint.pprint(response.model)
# Out:
# 'text-embedding-3-small'

# %%
pprint.pprint(response.usage)
# Out:
# Usage(prompt_tokens=8, total_tokens=8)

# %%
pprint.pprint(response.data[0].embedding)
# Out:
# [-0.04088960960507393,
#  0.011142821051180363,
#  -0.05352235957980156,
#  -0.07611864060163498,
#  0.027129346504807472,
#  -0.02209005318582058,
#  0.017971178516745567,
#  0.024690236896276474,
#  -0.032628849148750305,
#  -0.03835845738649368,
#  0.005128459073603153,
#  -0.03196154534816742,
#  0.0036672940477728844,
#  -0.01005557645112276,
#  -0.002033550525084138,
#  -0.010751643218100071,
#  0.014139935374259949,
#  -0.013668220490217209,
#  0.0034975919406861067,
#  0.031133169308304787,
#  0.014853260479867458,
#  0.011735341511666775,
#  -0.0187535360455513,
#  0.00983697734773159,
#  -0.026968274265527725,
#  0.008122696541249752,
#  -0.008738227188587189,
#  -0.007179267704486847,
#  -6.858199776615947e-05,
#  0.010170629248023033,
#  0.0468263104557991,
#  -0.01732688583433628,
#  0.017050759866833687,
#  -0.007185020018368959,
#  -0.015520564280450344,
#  -0.030281782150268555,
#  0.04259238392114639,
#  0.007518671918660402,
#  0.03953199088573456,
# ...

# %% [markdown]
# # Vector Database

# %%
# !pip install --upgrade --quiet  pinecone-client langchain-openai tiktoken  pypdf
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.0/284.0 kB 8.5 MB/s eta 0:00:00

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.vectorstores import Pinecone
from langchain_openai import OpenAIEmbeddings, ChatOpenAI

# %% [markdown]
# 1. PDF loader

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("/content/TheLetter.pdf")
pages = loader.load()

# %%
pages[0]
# Out:
# Document(page_content='The Letter  (Arnold Lobel ) \n \n \nEvery day, Toad sat on his porch waiting for the mail. Every day, he waited and waited, but \nno mail ever came. This was his sad time of the day.  Sometimes, Toad’s best friend, Frog, \nwould sit with him, and they would be sad together.  \n \nBut today, Frog had a different idea . Instead of waiting with Toad , Frog said, “I have to go \nhome now, Toad. There is something important I forgot to do.” With that,  Frog hurried home.  \n \nToad wondered what Frog felt was more important than being sad together, but he was \nfeeling tired and decided to take a nap. However, in a very short time, Frog ran back to \nToad’s house. Toad was in bed, so Frog shook him. “Toad, I thi nk you should get up and wait \nfor the mail some more!”  \n \n“No” said Toad with a yawn, “I’m tired of waiting for the mail.”  \n \nFrog looked out of Toad’s  window and down the road. “Toad, get out of bed!” he pleaded. \n“You never know when someone ma y
# ...

# %%
len(pages[0].page_content)
# Out:
# 1898

# %% [markdown]
# 2. Chunk text

# %%
text_splitter = RecursiveCharacterTextSplitter(
    # Set a really small chunk size, just to show.
    chunk_size=200,
    chunk_overlap=100,
    length_function=len,
    is_separator_regex=False,
)

# %%
# texts = text_splitter.create_documents(pages[0].page_content)

# %%
# texts

# %%
# texts = text_splitter.split_text(pages[0].page_content)

# %%
# texts

# %%
# texts = text_splitter.split_documents(pages)

# %%
# texts

# %%
docs = text_splitter.split_documents(pages)

# %%
len(docs)
# Out:
# 22

# %% [markdown]
# 3. Create Embeddings

# %%
from google.colab import userdata
openai_embeddings_api = userdata.get('Embeddings')

# %%
embeddings = OpenAIEmbeddings(api_key = openai_embeddings_api)

# %%
embeddings
# Out:
# OpenAIEmbeddings(client=<openai.resources.embeddings.Embeddings object at 0x780946d23dc0>, async_client=<openai.resources.embeddings.AsyncEmbeddings object at 0x780946d227d0>, model='text-embedding-ada-002', dimensions=None, deployment='text-embedding-ada-002', openai_api_version='', openai_api_base=None, openai_api_type='', openai_proxy='', embedding_ctx_length=8191, openai_api_key='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', openai_organization=None, allowed_special=set(), disallowed_special='all', chunk_size=1000, max_retries=2, request_timeout=None, headers=None, tiktoken_enabled=True, tiktoken_model_name=None, show_progress_bar=False, model_kwargs={}, skip_empty=False, default_headers=None, default_query=None, retry_min_seconds=4, retry_max_seconds=20, http_client=None)

# %%
query_embeddings = embeddings.embed_query("How are you?")

# %%
query_embeddings[:5]
# Out:
# [-0.01677368952027738,
#  -0.012034906992839031,
#  0.006741519544504659,
#  -0.026152659179575422,
#  -0.016058865917412825]

# %% [markdown]
# This will be the dimension we will be passing to our pinecone index

# %%
len(query_embeddings)
# Out:
# 1536

# %% [markdown]
# 4. Vector Database

# %% [markdown]
# 1. PineCone - Made it super complicated for simple task.

# %%
from google.colab import userdata
PINECONE_API_KEY = userdata.get('pinecone')

# %%
# !pip3 install -U pinecone-client

# %% [markdown]
# Langchain will provide AttributeError: init is no longer a top-level attribute of the pinecone package.
#
#
# To solve use: https://docs.pinecone.io/docs/new-api

# %%
from pinecone import Pinecone

pc = Pinecone(api_key=PINECONE_API_KEY)

# %%
# # First, check if our index already exists. If it doesn't, we create it
# if index_name not in pc.list_indexes():
#     # we create a new index
#     pc.create_index(
#     name="serverless-index",
#     dimension=8,
#     metric="euclidean",
#     spec=ServerlessSpec(
#         cloud='aws',
#         region='us-west-2'
#     )
# )

# %% [markdown]
# ```
# Langchain Intergration with pinecone is different from official langchain docs
#
# instead refere the docs below from pinecone
#
#
# ```
# ---
#
# ## [PineCone-langchain-docs](https://docs.pinecone.io/docs/langchain)

# %%
pc.list_indexes()
# Out:
# {'indexes': [{'dimension': 1536,
#               'host': 'pinecone-tutorial-wnz81jv.svc.gcp-starter.pinecone.io',
#               'metric': 'cosine',
#               'name': 'pinecone-tutorial',
#               'spec': {'pod': {'environment': 'gcp-starter',
#                                'pod_type': 'starter',
#                                'pods': 1,
#                                'replicas': 1,
#                                'shards': 1}},
#               'status': {'ready': True, 'state': 'Ready'}}]}

# %%
pc.describe_index("pinecone-tutorial")
# Out:
# {'dimension': 1536,
#  'host': 'pinecone-tutorial-wnz81jv.svc.gcp-starter.pinecone.io',
#  'metric': 'cosine',
#  'name': 'pinecone-tutorial',
#  'spec': {'pod': {'environment': 'gcp-starter',
#                   'pod_type': 'starter',
#                   'pods': 1,
#                   'replicas': 1,
#                   'shards': 1}},
#  'status': {'ready': True, 'state': 'Ready'}}

# %%
index = pc.Index("pinecone-tutorial")
index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'namespaces': {},
#  'total_vector_count': 0}

# %% [markdown]
# 2. Chroma DB

# %%
# !pip install chromadb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.0/509.0 kB 11.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 22.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 14.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 kB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 39.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 71.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.6/105.6 kB 16.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 11.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
from langchain_community.vectorstores import Chroma
# load it into Chroma
db = Chroma.from_documents(docs, embeddings)

# %%
db

# %%
query = "who is toads friend?"
matching_results = db.similarity_search(query, k=2)

# %%
matching_results
# Out:
# [Document(page_content='Toad was shocked. “You  did? What did you write in the letter?”  \n \n“I wrote, ‘Dear Toad, I am glad tha t you are my best friend. Frog.’”  \n \n“Oh, that makes a very good letter.”', metadata={'page': 0, 'source': '/content/TheLetter.pdf'}),
#  Document(page_content='no mail ever came. This was his sad time of the day.  Sometimes, Toad’s best friend, Frog, \nwould sit with him, and they would be sad together.', metadata={'page': 0, 'source': '/content/TheLetter.pdf'})]

# %%
# print results
print(matching_results[0].page_content)
# Out:
# Toad was shocked. “You  did? What did you write in the letter?”
#
# “I wrote, ‘Dear Toad, I am glad tha t you are my best friend. Frog.’”
#
# “Oh, that makes a very good letter.”

# %% [markdown]
# Save and Load from Disk

# %%
# save to disk
db2 = Chroma.from_documents(docs, embeddings, persist_directory="chroma_db")
matching_results = db2.similarity_search(query)

# %%
# print results
print(matching_results[0].page_content)
# Out:
# Toad was shocked. “You  did? What did you write in the letter?”
#
# “I wrote, ‘Dear Toad, I am glad tha t you are my best friend. Frog.’”
#
# “Oh, that makes a very good letter.”

# %%
# load from disk
db3 = Chroma(persist_directory="chroma_db", embedding_function=embeddings)
matching_results = db3.similarity_search(query)
print(matching_results[0].page_content)
# Out:
# Toad was shocked. “You  did? What did you write in the letter?”
#
# “I wrote, ‘Dear Toad, I am glad tha t you are my best friend. Frog.’”
#
# “Oh, that makes a very good letter.”

# %% [markdown]
# 5. Passing to LLM

# %%
from langchain.chains.question_answering import load_qa_chain
from langchain_openai import OpenAI

# %%
from google.colab import userdata
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')

# %%
llm=OpenAI(temperature=0.5, openai_api_key = OPENAI_API_KEY)

chain=load_qa_chain(llm,chain_type="stuff")

# %%
query = "who is toads friend?"

matching_results = db3.similarity_search(query)


response=chain.run(input_documents = matching_results, question=query)

# %%
response
# Out:
# " Toad's friend is Frog."
